# %% [markdown]
# # Project #1: Research Design Write-Up Part 1
# ***
#
# ## "A problem well-stated is half-solved" -- Charles Kettering
#
# This first project will enable me to create a framework to scope out data science projects. This framework will provide me with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.
#
# *Goal: Create a structured iPython notebook using markup*
#
# ### DELIVERABLES
#
# #### Completed iPython Notebook
#
# __Requirements:__
#
# - Identify features of the dataset, including the outcome and covariates/predictors
# - Create a data dictionary with classification of available variables
# - Write a high quality problem statement
# - State the risks and assumptions of your data
# - Outline exploratory analysis methods
#
# __Bonus:__
#
# - Practice writing an alternative problem statement for your dataset
# - Articulate the risks and assumptions of this alternative model
#
#
# ### Read and evaluate the following problem statement:
#
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.
#
# #### Let's get started with our dataset
# 1. Create a data dictionary
#    >Answer:
#
# | __Variable__           | __Description__                 | __Type of Variable__ |
# | -----------------------|---------------------------------| ------------------|
# | Age                    | Customer Age                    | Continuous        |
# | Gender                 | Customer Gender                 | Categorical       |
# | Location               | Customer Location               | Nominal           |
# | Profession             | Customer profession             | Nominal           |
# | Days since last log in | Number of days since last login | Continuous        |
# | Activity score         | 1=Active user, 0=Inactive user  | Categorical       |
# | Account type           | 0=Free tier, 1=Paying           | Categorical       |
#
# 2. What is the outcome?
#
#    >Answer: Conversion from free-tier to paying customers.
#
# 3. What are the predictors/covariates?
#
#    >Answer: Age, Gender, Location, Profession, Days since last log in, Activity Score.
#
# 4. What timeframe is this data relevent for?
#
#    >Answer: January to April 2015
#
# 5. What is the hypothesis?
#
#    >Answer: The hypothesis is that customers who are active users, have fewer days since last log in are more likely to convert from free-tier to paying customers.
#
#
# ### Using the above information, write a well-formed problem statement.
#
# #### Problem Statement
#
# >It is important to determine if customers will convert from free-tier to paying customers. We want to create a model to predict the determinants for a customer's conversion, so as to better direct marketing and sales efforts, and also to predict earnings for the company.
#
# >The hypothesis is that free-tier customers who are active users, and spend less time between log in episodes, are more likely to convert to paying ones.
#
# Exploratory Analysis Plan
#
# Using the lab from a class as a guide, create an exploratory analysis plan.
#
# 1. What are the goals of the exploratory analysis?
#
#    >Answer: Exploratory analysis allows for better understanding of the data, to describe the data structure and information that has been collected, as well as to explore variables and data types.
#
# 2. a) What are the assumptions of the distribution of data?
#
#    >Answer: A normal distribution is often assumed. The central limit theorem is also a fundamental tool, which states that with some assumptions, sampling distributions are normal with a specific mean and variance.
#
# 2. b) How will you determine the distribution of your data?
#
#    >Answer: Descriptive statistics will be reported, followed by measures of skewness and kurtosis, and histogram/box plots.
#
# 3. a) How might outliers impact your analysis?
#
#    >Answer: Outliers increase error variance and reduce the power of statistical tests. If non-randomly distributed, they can decrease normality and also bias or influence estimates.
#
# 3. b) How will you test for outliers?
#
#    >Answer: Visual inspection of the data, measures of the mean, median, standard deviation and variance will help to identify outlying data points.
#
# 4. a) What is colinearity?
#
#    >Answer: It is a phenomenon in which two (or more) predictor variables in a multiple regression model are highly correlated. In this situation, the coefficient estimates of the multiple regression may change erratically in response to small changes in the model or in the data.
#
# 4. b) How will you test for colinearity?
#
#    >Answer: Tests of correlation between predictor variables may reveal colinearity.
#
# 5. What are the risks and assumptions of your data?
#
#   > The risks include the lack of time-based information on the data, so at best, only correlations can be assumed, not causation. It is also assumed that this data has been randomly sampled with no bias and that there are no other confounding variables.
#
# #### What is your exploratory analysis plan?
#
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.
#
#    >Answer:
# 1. Collect data
# 2. Review dataset
# 3. Plot density and box plots for continuous variables
# 4. Perform descriptive statistics and review Mean, Mode, Median, and Standard Deviation
# 5. Plot scatter plot of continuous variables and review correlation coefficient
# 6. Review the skewness and kurtosis
# 7. Create dummy variables for categorical variables
# 8. Report the correlations that exist
# 9. A heatmap will help to visualize the above correlations
# 10. Using statsmodel, perform regression to review the predictive value of age, location, profession, days since last log in and activity score.
# 11. Report the p values of the regression model.
#
# ***
#
# *Bonus Questions:*
#
# *Outline your analysis method for predicting your outcome*
#
# >#Using statsmodels to estimate the association between age, location, profession, days since last log in and activity score.
#
# >lm = smf.ols(formula='convert ~ age + location + profession + activity + days_since_last_log_in, data=data).fit()
# >lm.summary()
#
# >#using logistic regression (for binary outcome)
#
# >logit = smf.Logit(data['convert'], data[relevant_columns])
# >result = logit.fit()
#
# *Write an alternative problem statement for your dataset*
# >The likelihood of a customer to remain active and have fewer days between log ins depends on their account type, where paying customers would be more likely to remain active.
#
# *Articulate the assumptions and risks of the alternative model*
# >It is assumed that there is a monetary disincentive for paying customers not to use their account, and the risks include missing out on confounding variables.
